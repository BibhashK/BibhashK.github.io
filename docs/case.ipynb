# %% [markdown]
# # A case study of wines
#
# ## winequality-red.csv and winequality-white.csv

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
red_df = pd.read_csv("winequality-red.csv",sep=';')
white_df = pd.read_csv("winequality-white.csv",sep=';')

# %%
red_df.head(3)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free_sulfur_dioxide  total_sulfur-dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5

# %%
white_df.head(3)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6

# %%
red_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed_acidity           1599 non-null float64
# volatile_acidity        1599 non-null float64
# citric_acid             1599 non-null float64
# residual_sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free_sulfur_dioxide     1599 non-null float64
# total_sulfur-dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
white_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed_acidity           4898 non-null float64
# volatile_acidity        4898 non-null float64
# citric_acid             4898 non-null float64
# residual_sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free_sulfur_dioxide     4898 non-null float64
# total_sulfur_dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
red_df.shape
# Out:
# (1599, 12)

# %%
white_df.shape
# Out:
# (4898, 12)

# %% [markdown]
# # Creating color columns

# %%
red_list = ['red']*len(red_df.index)
color_red = np.array(red_list)

# %%
white_list = ['white']*len(white_df.index)
color_white = np.array(white_list)

# %%
red_df['color_red'] = color_red
red_df.head(3)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free_sulfur_dioxide  total_sulfur-dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality color_red
# 0      9.4        5       red
# 1      9.8        5       red
# 2      9.8        5       red

# %%
white_df['color_white'] = color_white
white_df.head(3)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
#
#    alcohol  quality color_white
# 0      8.8        6       white
# 1      9.5        6       white
# 2     10.1        6       white

# %% [markdown]
# ### Appending Data

# %%
df = red_df.append(white_df,ignore_index=True)

# %%
df
# Out:
#         alcohol  chlorides  citric_acid color_red color_white  density  \
# 0      9.400000      0.076         0.00       red         NaN  0.99780
# 1      9.800000      0.098         0.00       red         NaN  0.99680
# 2      9.800000      0.092         0.04       red         NaN  0.99700
# 3      9.800000      0.075         0.56       red         NaN  0.99800
# 4      9.400000      0.076         0.00       red         NaN  0.99780
# 5      9.400000      0.075         0.00       red         NaN  0.99780
# 6      9.400000      0.069         0.06       red         NaN  0.99640
# 7     10.000000      0.065         0.00       red         NaN  0.99460
# 8      9.500000      0.073         0.02       red         NaN  0.99680
# 9     10.500000      0.071         0.36       red         NaN  0.99780
# 10     9.200000      0.097         0.08       red         NaN  0.99590
# 11    10.500000      0.071         0.36       red         NaN  0.99780
# 12     9.900000      0.089         0.00       red         NaN  0.99430
# 13     9.100000      0.114         0.29       red         NaN  0.99740
# 14     9.200000      0.176         0.18       red         NaN  0.99860
# 15     9.200000      0.170         0.19       red         NaN  0.99860
# 16    10.500000      0.092         0.56       red         NaN  0.99690
# 17     9.300000      0.368         0.28       red         NaN  0.99680
# 18     9.000000      0.086         0.08       red         NaN  0.99740
# 19     9.200000      0.341         0.51       red         NaN  0.99690
# 20     9.400000      0.077         0.48       red         NaN  0.99680
# 21     9.700000      0.082         0.31       red         NaN  0.99820
# 22     9.500000      0.106         0.21       red         NaN  0.99660
# 23     9.400000      0.084         0.11       red         NaN  0.99680
# 24     9.700000      0.085         0.14       red         NaN  0.99680
# 25     9.300000      0.080         0.16       red         NaN  0.99550
# 26     9.500000      0.080         0.24       red         NaN  0.99620
# 27     9.500000      0.106         0.21       red         NaN  0.99660
# 28     9.400000      0.080         0.00       red         NaN  0.99720
# 29     9.800000      0.082         0.00       red         NaN  0.99640
# ...         ...        ...          ...       ...         ...      ...
# 6467  10.800000      0.046         0.31       NaN       white  0.99324
# 6468   9.800000      0.032         0.33       NaN       white  0.99626
# 6469  11.450000      0.021         0.28       NaN       white  0.99188
# 6470  12.050000      0.015         0.40       NaN       white  0.98970
# 6471   9.700000      0.032         0.41       NaN       white  0.99622
# 6472  11.900000      0.030         0.32       NaN       white  0.99044
# 6473  10.000000      0.048         0.36       NaN       white  0.99282
# 6474   9.700000      0.035         0.26       NaN       white  0.99245
# 6475  11.600000      0.038         0.42       NaN       white  0.99132
# 6476   8.800000      0.032         0.00       NaN       white  0.99286
# 6477   9.500000      0.035         0.02       NaN       white  0.99234
# 6478   9.533333      0.046         0.40       NaN       white  0.99494
# 6479   9.533333      0.046         0.40       NaN       white  0.99494
# 6480   9.400000      0.030         0.27       NaN       white  0.99540
# 6481  10.700000      0.037         0.13       NaN       white  0.99184
# 6482  11.500000      0.035         0.17       NaN       white  0.98964
# 6483   9.600000      0.048         0.38       NaN       white  0.99492
# 6484   9.550000      0.046         0.40       NaN       white  0.99494
# 6485  12.150000      0.028         0.28       NaN       white  0.99168
# 6486  13.000000      0.023         0.22       NaN       white  0.98928
# 6487   9.200000      0.052         0.36       NaN       white  0.99330
# 6488   9.400000      0.030         0.27       NaN       white  0.99540
# 6489  11.800000      0.036         0.29       NaN       white  0.98938
# 6490  10.600000      0.038         0.32       NaN       white  0.99074
# 6491   9.700000      0.032         0.38       NaN       white  0.99298
# 6492  11.200000      0.039         0.29       NaN       white  0.99114
# 6493   9.600000      0.047         0.36       NaN       white  0.99490
# 6494   9.400000      0.041         0.19       NaN       white  0.99254
# 6495  12.800000      0.022         0.30       NaN       white  0.98869
# 6496  11.800000      0.020         0.38       NaN       white  0.98941
#
#       fixed_acidity  free_sulfur_dioxide    pH  quality  residual_sugar  \
# 0               7.4                 11.0  3.51        5            1.90
# 1               7.8                 25.0  3.20        5            2.60
# 2               7.8                 15.0  3.26        5            2.30
# 3              11.2                 17.0  3.16        6            1.90
# 4               7.4                 11.0  3.51        5            1.90
# 5               7.4                 13.0  3.51        5            1.80
# 6               7.9                 15.0  3.30        5            1.60
# 7               7.3                 15.0  3.39        7            1.20
# 8               7.8                  9.0  3.36        7            2.00
# 9               7.5                 17.0  3.35        5            6.10
# 10              6.7                 15.0  3.28        5            1.80
# 11              7.5                 17.0  3.35        5            6.10
# 12              5.6                 16.0  3.58        5            1.60
# 13              7.8                  9.0  3.26        5            1.60
# 14              8.9                 52.0  3.16        5            3.80
# 15              8.9                 51.0  3.17        5            3.90
# 16              8.5                 35.0  3.30        7            1.80
# 17              8.1                 16.0  3.11        5            1.70
# 18              7.4                  6.0  3.38        4            4.40
# 19              7.9                 17.0  3.04        6            1.80
# 20              8.9                 29.0  3.39        6            1.80
# 21              7.6                 23.0  3.52        5            2.30
# 22              7.9                 10.0  3.17        5            1.60
# 23              8.5                  9.0  3.17        5            2.30
# 24              6.9                 21.0  3.43        6            2.40
# 25              6.3                 11.0  3.34        5            1.40
# 26              7.6                  4.0  3.28        5            1.80
# 27              7.9                 10.0  3.17        5            1.60
# 28              7.1                 14.0  3.47        5            1.90
# 29              7.8                  8.0  3.38        6            2.00
# ...             ...                  ...   ...      ...             ...
# 6467            5.8                 42.0  3.31        6            4.50
# 6468            6.6                  8.0  3.19        6           10.10
# 6469            6.1                 29.0  3.15        7            6.60
# 6470            5.0                 20.0  3.37        6            1.90
# 6471            6.0                 50.0  3.14        5           12.40
# 6472            5.7                 33.0  3.33        6            1.60
# 6473            5.6                 16.0  3.49        6            2.50
# 6474            7.4                 18.0  3.12        6            1.20
# 6475            6.2                 34.0  3.36        7            2.50
# 6476            5.9                 12.0  3.25        5            0.80
# 6477            6.2                  6.0  3.24        4            0.90
# 6478            6.6                 68.0  3.15        6            8.10
# 6479            6.6                 68.0  3.15        6            8.10
# 6480            5.0                 34.0  3.07        6           11.75
# 6481            5.5                 45.0  3.26        5            1.30
# 6482            4.9                 60.0  3.27        6            1.90
# 6483            6.5                 68.0  3.14        5            8.30
# 6484            6.6                 68.0  3.15        6            8.10
# 6485            6.2                 45.0  3.21        7            5.70
# 6486            6.2                  5.0  3.04        7            1.90
# 6487            6.8                 38.0  3.04        5            1.20
# 6488            4.9                 34.0  3.07        6           11.75
# 6489            6.1                 25.0  3.06        6            2.20
# 6490            5.7                 38.0  3.24        6            0.90
# 6491            6.5                 29.0  3.29        5            1.30
# 6492            6.2                 24.0  3.27        6            1.60
# 6493            6.6                 57.0  3.15        5            8.00
# 6494            6.5                 30.0  2.99        6            1.20
# 6495            5.5                 20.0  3.34        7            1.10
# 6496            6.0                 22.0  3.26        6            0.80
#
#       sulphates  total_sulfur-dioxide  total_sulfur_dioxide  volatile_acidity
# 0          0.56                  34.0                   NaN             0.700
# 1          0.68                  67.0                   NaN             0.880
# 2          0.65                  54.0                   NaN             0.760
# 3          0.58                  60.0                   NaN             0.280
# 4          0.56                  34.0                   NaN             0.700
# 5          0.56                  40.0                   NaN             0.660
# 6          0.46                  59.0                   NaN             0.600
# 7          0.47                  21.0                   NaN             0.650
# 8          0.57                  18.0                   NaN             0.580
# 9          0.80                 102.0                   NaN             0.500
# 10         0.54                  65.0                   NaN             0.580
# 11         0.80                 102.0                   NaN             0.500
# 12         0.52                  59.0                   NaN             0.615
# 13         1.56                  29.0                   NaN             0.610
# 14         0.88                 145.0                   NaN             0.620
# 15         0.93                 148.0                   NaN             0.620
# 16         0.75                 103.0                   NaN             0.280
# 17         1.28                  56.0                   NaN             0.560
# 18         0.50                  29.0                   NaN             0.590
# 19         1.08                  56.0                   NaN             0.320
# 20         0.53                  60.0                   NaN             0.220
# 21         0.65                  71.0                   NaN             0.390
# 22         0.91                  37.0                   NaN             0.430
# 23         0.53                  67.0                   NaN             0.490
# 24         0.63                  40.0                   NaN             0.400
# 25         0.56                  23.0                   NaN             0.390
# 26         0.59                  11.0                   NaN             0.410
# 27         0.91                  37.0                   NaN             0.430
# 28         0.55                  35.0                   NaN             0.710
# 29         0.59                  16.0                   NaN             0.645
# ...         ...                   ...                   ...               ...
# 6467       0.64                   NaN                 124.0             0.230
# 6468       0.51                   NaN                  81.0             0.240
# 6469       0.36                   NaN                 132.0             0.320
# 6470       0.55                   NaN                  98.0             0.200
# 6471       0.60                   NaN                 179.0             0.420
# 6472       0.52                   NaN                 122.0             0.210
# 6473       0.49                   NaN                 125.0             0.200
# 6474       0.41                   NaN                  97.0             0.220
# 6475       0.59                   NaN                 117.0             0.380
# 6476       0.36                   NaN                  82.0             0.540
# 6477       0.35                   NaN                  81.0             0.530
# 6478       0.50                   NaN                 170.0             0.340
# 6479       0.50                   NaN                 170.0             0.340
# 6480       0.50                   NaN                 118.0             0.235
# 6481       0.38                   NaN                 156.0             0.320
# 6482       0.35                   NaN                 148.0             0.470
# 6483       0.50                   NaN                 174.0             0.330
# 6484       0.50                   NaN                 170.0             0.340
# 6485       1.08                   NaN                 121.0             0.210
# 6486       0.79                   NaN                  56.0             0.410
# 6487       0.54                   NaN                 127.0             0.220
# 6488       0.50                   NaN                 118.0             0.235
# 6489       0.44                   NaN                 100.0             0.340
# 6490       0.46                   NaN                 121.0             0.210
# 6491       0.54                   NaN                 112.0             0.230
# 6492       0.50                   NaN                  92.0             0.210
# 6493       0.46                   NaN                 168.0             0.320
# 6494       0.46                   NaN                 111.0             0.240
# 6495       0.38                   NaN                 110.0             0.290
# 6496       0.32                   NaN                  98.0             0.210
#
# [6497 rows x 15 columns]

# %%
df.to_csv('winequality-edited.csv',index=False)

# %%
df.shape
# Out:
# (6497, 15)

# %% [markdown]
# # Appending Data Continued

# %% [markdown]
# # EDA WITH VISUALS

# %%
df.head(2)
# Out:
#    alcohol  chlorides  citric_acid color_red color_white  density  \
# 0      9.4      0.076          0.0       red         NaN   0.9978
# 1      9.8      0.098          0.0       red         NaN   0.9968
#
#    fixed_acidity  free_sulfur_dioxide    pH  quality  residual_sugar  \
# 0            7.4                 11.0  3.51        5             1.9
# 1            7.8                 25.0  3.20        5             2.6
#
#    sulphates  total_sulfur-dioxide  total_sulfur_dioxide  volatile_acidity
# 0       0.56                  34.0                   NaN              0.70
# 1       0.68                  67.0                   NaN              0.88

# %%
df['fixed_acidity'].hist()

# %%
df['pH'].hist()

# %%
df['total_sulfur-dioxide'].hist()

# %%
df['alcohol'].hist()

# %% [markdown]
# # scatterplots of quality Against Various Features

# %%
df.plot(x='quality',y='volatile_acidity',kind='scatter');

# %%
df.plot(x='quality',y='residual_sugar',kind='scatter',color='y');

# %%
df.plot(x='quality',y='pH',kind='scatter',color='r');

# %%
df.plot(x='quality',y='alcohol',kind='scatter',color='green');

# %% [markdown]
# # Drawing conclusions using groupby with pandas

# %% [markdown]
# ## is a certain type of wine assocaited with higher quality?

# %%
df.groupby('color_red').mean()
# Out:
#              alcohol  chlorides  citric_acid   density  fixed_acidity  \
# color_red
# red        10.422983   0.087467     0.270976  0.996747       8.319637
#
#            free_sulfur_dioxide        pH   quality  residual_sugar  sulphates  \
# color_red
# red                  15.874922  3.311113  5.636023        2.538806   0.658149
#
#            total_sulfur-dioxide  total_sulfur_dioxide  volatile_acidity
# color_red
# red                   46.467792                   NaN          0.527821

# %%
df.groupby('color_white').mean()
# Out:
#                alcohol  chlorides  citric_acid   density  fixed_acidity  \
# color_white
# white        10.514267   0.045772     0.334192  0.994027       6.854788
#
#              free_sulfur_dioxide        pH   quality  residual_sugar  \
# color_white
# white                  35.308085  3.188267  5.877909        6.391415
#
#              sulphates  total_sulfur-dioxide  total_sulfur_dioxide  \
# color_white
# white         0.489847                   NaN            138.360657
#
#              volatile_acidity
# color_white
# white                0.278241

# %% [markdown]
# ## what level of acidity receives the highest average rating?

# %%
df.describe()
# Out:
#            alcohol    chlorides  citric_acid      density  fixed_acidity  \
# count  6497.000000  6497.000000  6497.000000  6497.000000    6497.000000
# mean     10.491801     0.056034     0.318633     0.994697       7.215307
# std       1.192712     0.035034     0.145318     0.002999       1.296434
# min       8.000000     0.009000     0.000000     0.987110       3.800000
# 25%       9.500000     0.038000     0.250000     0.992340       6.400000
# 50%      10.300000     0.047000     0.310000     0.994890       7.000000
# 75%      11.300000     0.065000     0.390000     0.996990       7.700000
# max      14.900000     0.611000     1.660000     1.038980      15.900000
#
#        free_sulfur_dioxide           pH      quality  residual_sugar  \
# count          6497.000000  6497.000000  6497.000000     6497.000000
# mean             30.525319     3.218501     5.818378        5.443235
# std              17.749400     0.160787     0.873255        4.757804
# min               1.000000     2.720000     3.000000        0.600000
# 25%              17.000000     3.110000     5.000000        1.800000
# 50%              29.000000     3.210000     6.000000        3.000000
# 75%              41.000000     3.320000     6.000000        8.100000
# max             289.000000     4.010000     9.000000       65.800000
#
#          sulphates  total_sulfur-dioxide  total_sulfur_dioxide  \
# count  6497.000000           1599.000000           4898.000000
# mean      0.531268             46.467792            138.360657
# std       0.148806             32.895324             42.498065
# min       0.220000              6.000000              9.000000
# 25%       0.430000             22.000000            108.000000
# 50%       0.510000             38.000000            134.000000
# 75%       0.600000             62.000000            167.000000
# max       2.000000            289.000000            440.000000
#
#        volatile_acidity
# count       6497.000000
# mean           0.339666
# std            0.164636
# min            0.080000
# 25%            0.230000
# 50%            0.290000
# 75%            0.400000
# max            1.580000

# %%
df['pH'].describe()
# Out:
# count    6497.000000
# mean        3.218501
# std         0.160787
# min         2.720000
# 25%         3.110000
# 50%         3.210000
# 75%         3.320000
# max         4.010000
# Name: pH, dtype: float64

# %%
# Bin edges that will be used to "cut" the data into groups
bin_edges = [2.72,3.11,3.21,3.32,4.01]

# %%
bin_names=['fixed_acidity' ,'volatile_acidity' ,'citric_acid' ,'residual_sugar' ]

# %%
df['acidity_levels'] = pd.cut(df['pH'], bin_edges, labels=bin_names)

# %%
df.head()
# Out:
#    alcohol  chlorides  citric_acid color_red color_white  density  \
# 0      9.4      0.076         0.00       red         NaN   0.9978
# 1      9.8      0.098         0.00       red         NaN   0.9968
# 2      9.8      0.092         0.04       red         NaN   0.9970
# 3      9.8      0.075         0.56       red         NaN   0.9980
# 4      9.4      0.076         0.00       red         NaN   0.9978
#
#    fixed_acidity  free_sulfur_dioxide    pH  quality  residual_sugar  \
# 0            7.4                 11.0  3.51        5             1.9
# 1            7.8                 25.0  3.20        5             2.6
# 2            7.8                 15.0  3.26        5             2.3
# 3           11.2                 17.0  3.16        6             1.9
# 4            7.4                 11.0  3.51        5             1.9
#
#    sulphates  total_sulfur-dioxide  total_sulfur_dioxide  volatile_acidity  \
# 0       0.56                  34.0                   NaN              0.70
# 1       0.68                  67.0                   NaN              0.88
# 2       0.65                  54.0                   NaN              0.76
# 3       0.58                  60.0                   NaN              0.28
# 4       0.56                  34.0                   NaN              0.70
#
#      acidity_levels
# 0    residual_sugar
# 1  volatile_acidity
# 2       citric_acid
# 3  volatile_acidity
# 4    residual_sugar

# %%
# Find the mean quality of each acidity level with groupby
df.groupby(['fixed_acidity' ,'volatile_acidity' ,'citric_acid' ,'residual_sugar' ]).mean()
# Out:
#                                                              alcohol  \
# fixed_acidity volatile_acidity citric_acid residual_sugar
# 3.8           0.310            0.02        11.10           12.400000
# 3.9           0.225            0.40        4.20            12.800000
# 4.2           0.170            0.36        1.80            12.000000
#               0.215            0.23        5.10             8.000000
# 4.4           0.320            0.39        4.30            12.800000
#               0.460            0.10        2.80            13.100000
#               0.540            0.09        5.10            12.200000
# 4.5           0.190            0.21        0.95             8.000000
# 4.6           0.445            0.00        1.40            10.200000
#               0.520            0.15        2.10            13.100000
# 4.7           0.145            0.29        1.00            11.300000
#               0.335            0.14        1.30            10.500000
#               0.455            0.18        1.90            14.000000
#               0.600            0.17        2.30            12.900000
#               0.670            0.09        1.00            13.600000
#               0.785            0.00        3.40            13.800000
# 4.8           0.130            0.32        1.20            11.800000
#               0.170            0.28        2.90            11.300000
#               0.210            0.21        10.20           12.200000
#               0.225            0.38        1.20            10.300000
#               0.260            0.23        10.60           11.500000
#               0.290            0.23        1.10            11.900000
#               0.330            0.00        6.50             9.900000
#               0.340            0.00        6.50             9.900000
#               0.650            0.12        1.10            13.500000
# 4.9           0.235            0.27        11.75            9.400000
#               0.330            0.31        1.20            14.000000
#               0.335            0.14        1.30            10.466667
#               0.345            0.34        1.00            10.100000
#               0.420            0.00        2.10            14.000000
# ...                                                              ...
# 12.6          0.380            0.66        2.60             9.800000
#               0.390            0.49        2.50            10.300000
#               0.410            0.54        2.80            11.300000
# 12.7          0.590            0.45        2.30             9.300000
#               0.600            0.49        2.80            11.400000
#                                0.65        2.30             9.900000
# 12.8          0.300            0.74        2.60            10.800000
#               0.615            0.66        5.80            10.000000
#               0.840            0.63        2.40            10.400000
# 12.9          0.350            0.49        5.80            12.000000
#               0.500            0.55        2.80            10.900000
# 13.0          0.320            0.65        2.60            10.600000
#               0.470            0.49        4.30            12.700000
# 13.2          0.380            0.55        2.70             9.400000
#               0.460            0.52        2.20             9.000000
# 13.3          0.290            0.75        2.80            11.400000
#               0.340            0.52        3.20             9.500000
#               0.430            0.58        1.90             9.000000
# 13.4          0.270            0.62        2.60             9.700000
# 13.5          0.530            0.79        4.80            13.000000
# 13.7          0.415            0.68        2.90            10.000000
# 13.8          0.490            0.67        3.00            12.000000
# 14.0          0.410            0.63        3.80            10.800000
# 14.2          0.270            0.49        1.10            11.100000
# 14.3          0.310            0.74        1.80             8.400000
# 15.0          0.210            0.44        2.20             9.200000
# 15.5          0.645            0.49        4.20            11.100000
# 15.6          0.645            0.49        4.20            11.100000
#               0.685            0.76        3.70            11.200000
# 15.9          0.360            0.65        7.50            14.900000
#
#                                                            chlorides  density  \
# fixed_acidity volatile_acidity citric_acid residual_sugar
# 3.8           0.310            0.02        11.10               0.036  0.99248
# 3.9           0.225            0.40        4.20                0.030  0.98900
# 4.2           0.170            0.36        1.80                0.029  0.98999
#               0.215            0.23        5.10                0.041  0.99688
# 4.4           0.320            0.39        4.30                0.030  0.98904
#               0.460            0.10        2.80                0.024  0.98816
#               0.540            0.09        5.10                0.038  0.99022
# 4.5           0.190            0.21        0.95                0.033  0.99332
# 4.6           0.445            0.00        1.40                0.053  0.99426
#               0.520            0.15        2.10                0.054  0.99340
# 4.7           0.145            0.29        1.00                0.042  0.99080
#               0.335            0.14        1.30                0.036  0.99212
#               0.455            0.18        1.90                0.036  0.98746
#               0.600            0.17        2.30                0.058  0.99320
#               0.670            0.09        1.00                0.020  0.98722
#               0.785            0.00        3.40                0.036  0.98981
# 4.8           0.130            0.32        1.20                0.042  0.98980
#               0.170            0.28        2.90                0.030  0.99020
#               0.210            0.21        10.20               0.037  0.99324
#               0.225            0.38        1.20                0.074  0.99132
#               0.260            0.23        10.60               0.034  0.99274
#               0.290            0.23        1.10                0.044  0.98924
#               0.330            0.00        6.50                0.028  0.99370
#               0.340            0.00        6.50                0.028  0.99390
#               0.650            0.12        1.10                0.013  0.99246
# 4.9           0.235            0.27        11.75               0.030  0.99540
#               0.330            0.31        1.20                0.016  0.98713
#               0.335            0.14        1.30                0.036  0.99212
#               0.345            0.34        1.00                0.068  0.99138
#               0.420            0.00        2.10                0.048  0.99154
# ...                                                              ...      ...
# 12.6          0.380            0.66        2.60                0.088  1.00100
#               0.390            0.49        2.50                0.080  0.99920
#               0.410            0.54        2.80                0.103  0.99939
# 12.7          0.590            0.45        2.30                0.082  1.00000
#               0.600            0.49        2.80                0.075  0.99940
#                                0.65        2.30                0.063  0.99970
# 12.8          0.300            0.74        2.60                0.095  0.99940
#               0.615            0.66        5.80                0.083  1.00220
#               0.840            0.63        2.40                0.088  0.99970
# 12.9          0.350            0.49        5.80                0.066  1.00140
#               0.500            0.55        2.80                0.072  1.00012
# 13.0          0.320            0.65        2.60                0.093  0.99960
#               0.470            0.49        4.30                0.085  1.00210
# 13.2          0.380            0.55        2.70                0.081  1.00060
#               0.460            0.52        2.20                0.071  1.00060
# 13.3          0.290            0.75        2.80                0.084  0.99860
#               0.340            0.52        3.20                0.094  1.00140
#               0.430            0.58        1.90                0.070  1.00040
# 13.4          0.270            0.62        2.60                0.082  1.00020
# 13.5          0.530            0.79        4.80                0.120  1.00180
# 13.7          0.415            0.68        2.90                0.085  1.00140
# 13.8          0.490            0.67        3.00                0.093  0.99860
# 14.0          0.410            0.63        3.80                0.089  1.00140
# 14.2          0.270            0.49        1.10                0.037  0.99200
# 14.3          0.310            0.74        1.80                0.075  1.00080
# 15.0          0.210            0.44        2.20                0.075  1.00005
# 15.5          0.645            0.49        4.20                0.095  1.00315
# 15.6          0.645            0.49        4.20                0.095  1.00315
#               0.685            0.76        3.70                0.100  1.00320
# 15.9          0.360            0.65        7.50                0.096  0.99760
#
#                                                            free_sulfur_dioxide  \
# fixed_acidity volatile_acidity citric_acid residual_sugar
# 3.8           0.310            0.02        11.10                          20.0
# 3.9           0.225            0.40        4.20                           29.0
# 4.2           0.170            0.36        1.80                           93.0
#               0.215            0.23        5.10                           64.0
# 4.4           0.320            0.39        4.30                           31.0
#               0.460            0.10        2.80                           31.0
#               0.540            0.09        5.10                           52.0
# 4.5           0.190            0.21        0.95                           89.0
# 4.6           0.445            0.00        1.40                           11.0
#               0.520            0.15        2.10                            8.0
# 4.7           0.145            0.29        1.00                           35.0
#               0.335            0.14        1.30                           69.0
#               0.455            0.18        1.90                           33.0
#               0.600            0.17        2.30                           17.0
#               0.670            0.09        1.00                            5.0
#               0.785            0.00        3.40                           23.0
# 4.8           0.130            0.32        1.20                           40.0
#               0.170            0.28        2.90                           22.0
#               0.210            0.21        10.20                          17.0
#               0.225            0.38        1.20                           47.0
#               0.260            0.23        10.60                          23.0
#               0.290            0.23        1.10                           38.0
#               0.330            0.00        6.50                           34.0
#               0.340            0.00        6.50                           33.0
#               0.650            0.12        1.10                            4.0
# 4.9           0.235            0.27        11.75                          34.0
#               0.330            0.31        1.20                           39.0
#               0.335            0.14        1.30                           69.0
#               0.345            0.34        1.00                           32.0
#               0.420            0.00        2.10                           16.0
# ...                                                                        ...
# 12.6          0.380            0.66        2.60                           10.0
#               0.390            0.49        2.50                            8.0
#               0.410            0.54        2.80                           19.0
# 12.7          0.590            0.45        2.30                           11.0
#               0.600            0.49        2.80                            5.0
#                                0.65        2.30                            6.0
# 12.8          0.300            0.74        2.60                            9.0
#               0.615            0.66        5.80                            7.0
#               0.840            0.63        2.40                           13.0
# 12.9          0.350            0.49        5.80                            5.0
#               0.500            0.55        2.80                            7.0
# 13.0          0.320            0.65        2.60                           15.0
#               0.470            0.49        4.30                            6.0
# 13.2          0.380            0.55        2.70                            5.0
#               0.460            0.52        2.20                           12.0
# 13.3          0.290            0.75        2.80                           23.0
#               0.340            0.52        3.20                           17.0
#               0.430            0.58        1.90                           15.0
# 13.4          0.270            0.62        2.60                            6.0
# 13.5          0.530            0.79        4.80                           23.0
# 13.7          0.415            0.68        2.90                           17.0
# 13.8          0.490            0.67        3.00                            6.0
# 14.0          0.410            0.63        3.80                            6.0
# 14.2          0.270            0.49        1.10                           33.0
# 14.3          0.310            0.74        1.80                            6.0
# 15.0          0.210            0.44        2.20                           10.0
# 15.5          0.645            0.49        4.20                           10.0
# 15.6          0.645            0.49        4.20                           10.0
#               0.685            0.76        3.70                            6.0
# 15.9          0.360            0.65        7.50                           22.0
#
#                                                              pH  quality  \
# fixed_acidity volatile_acidity citric_acid residual_sugar
# 3.8           0.310            0.02        11.10           3.75      6.0
# 3.9           0.225            0.40        4.20            3.57      8.0
# 4.2           0.170            0.36        1.80            3.65      7.0
#               0.215            0.23        5.10            3.42      3.0
# 4.4           0.320            0.39        4.30            3.46      8.0
#               0.460            0.10        2.80            3.48      6.0
#               0.540            0.09        5.10            3.41      7.0
# 4.5           0.190            0.21        0.95            3.34      5.0
# 4.6           0.445            0.00        1.40            3.79      5.0
#               0.520            0.15        2.10            3.90      4.0
# 4.7           0.145            0.29        1.00            3.76      6.0
#               0.335            0.14        1.30            3.47      5.0
#               0.455            0.18        1.90            3.21      7.0
#               0.600            0.17        2.30            3.85      6.0
#               0.670            0.09        1.00            3.30      5.0
#               0.785            0.00        3.40            3.53      6.0
# 4.8           0.130            0.32        1.20            3.42      7.0
#               0.170            0.28        2.90            3.38      7.0
#               0.210            0.21        10.20           3.66      7.0
#               0.225            0.38        1.20            3.31      6.0
#               0.260            0.23        10.60           3.46      7.0
#               0.290            0.23        1.10            3.28      6.0
#               0.330            0.00        6.50            3.35      5.0
#               0.340            0.00        6.50            3.36      6.0
#               0.650            0.12        1.10            3.32      4.0
# 4.9           0.235            0.27        11.75           3.07      6.0
#               0.330            0.31        1.20            3.33      8.0
#               0.335            0.14        1.30            3.47      5.0
#               0.345            0.34        1.00            3.24      5.0
#               0.420            0.00        2.10            3.71      7.0
# ...                                                         ...      ...
# 12.6          0.380            0.66        2.60            3.17      6.0
#               0.390            0.49        2.50            3.07      6.0
#               0.410            0.54        2.80            3.21      6.0
# 12.7          0.590            0.45        2.30            3.00      6.0
#               0.600            0.49        2.80            3.14      5.0
#                                0.65        2.30            3.03      5.0
# 12.8          0.300            0.74        2.60            3.20      7.0
#               0.615            0.66        5.80            3.07      7.0
#               0.840            0.63        2.40            3.10      6.0
# 12.9          0.350            0.49        5.80            3.20      7.0
#               0.500            0.55        2.80            3.09      6.0
# 13.0          0.320            0.65        2.60            3.05      5.0
#               0.470            0.49        4.30            3.30      6.0
# 13.2          0.380            0.55        2.70            2.98      5.0
#               0.460            0.52        2.20            3.10      6.0
# 13.3          0.290            0.75        2.80            3.04      7.0
#               0.340            0.52        3.20            3.05      6.0
#               0.430            0.58        1.90            3.06      5.0
# 13.4          0.270            0.62        2.60            3.16      6.0
# 13.5          0.530            0.79        4.80            3.18      5.0
# 13.7          0.415            0.68        2.90            3.06      6.0
# 13.8          0.490            0.67        3.00            3.02      6.0
# 14.0          0.410            0.63        3.80            3.01      6.0
# 14.2          0.270            0.49        1.10            3.15      6.0
# 14.3          0.310            0.74        1.80            2.86      6.0
# 15.0          0.210            0.44        2.20            3.07      7.0
# 15.5          0.645            0.49        4.20            2.92      5.0
# 15.6          0.645            0.49        4.20            2.92      5.0
#               0.685            0.76        3.70            2.95      7.0
# 15.9          0.360            0.65        7.50            2.98      5.0
#
#                                                            sulphates  \
# fixed_acidity volatile_acidity citric_acid residual_sugar
# 3.8           0.310            0.02        11.10                0.44
# 3.9           0.225            0.40        4.20                 0.36
# 4.2           0.170            0.36        1.80                 0.89
#               0.215            0.23        5.10                 0.44
# 4.4           0.320            0.39        4.30                 0.36
#               0.460            0.10        2.80                 0.34
#               0.540            0.09        5.10                 0.40
# 4.5           0.190            0.21        0.95                 0.42
# 4.6           0.445            0.00        1.40                 0.55
#               0.520            0.15        2.10                 0.56
# 4.7           0.145            0.29        1.00                 0.49
#               0.335            0.14        1.30                 0.46
#               0.455            0.18        1.90                 0.83
#               0.600            0.17        2.30                 0.60
#               0.670            0.09        1.00                 0.34
#               0.785            0.00        3.40                 0.92
# 4.8           0.130            0.32        1.20                 0.64
#               0.170            0.28        2.90                 0.34
#               0.210            0.21        10.20                0.48
#               0.225            0.38        1.20                 0.40
#               0.260            0.23        10.60                0.28
#               0.290            0.23        1.10                 0.34
#               0.330            0.00        6.50                 0.61
#               0.340            0.00        6.50                 0.61
#               0.650            0.12        1.10                 0.36
# 4.9           0.235            0.27        11.75                0.50
#               0.330            0.31        1.20                 0.59
#               0.335            0.14        1.30                 0.46
#               0.345            0.34        1.00                 0.40
#               0.420            0.00        2.10                 0.74
# ...                                                              ...
# 12.6          0.380            0.66        2.60                 0.68
#               0.390            0.49        2.50                 0.82
#               0.410            0.54        2.80                 0.76
# 12.7          0.590            0.45        2.30                 0.70
#               0.600            0.49        2.80                 0.57
#                                0.65        2.30                 0.57
# 12.8          0.300            0.74        2.60                 0.77
#               0.615            0.66        5.80                 0.73
#               0.840            0.63        2.40                 0.60
# 12.9          0.350            0.49        5.80                 0.66
#               0.500            0.55        2.80                 0.68
# 13.0          0.320            0.65        2.60                 0.61
#               0.470            0.49        4.30                 0.68
# 13.2          0.380            0.55        2.70                 0.54
#               0.460            0.52        2.20                 0.56
# 13.3          0.290            0.75        2.80                 0.68
#               0.340            0.52        3.20                 0.81
#               0.430            0.58        1.90                 0.49
# 13.4          0.270            0.62        2.60                 0.67
# 13.5          0.530            0.79        4.80                 0.77
# 13.7          0.415            0.68        2.90                 0.80
# 13.8          0.490            0.67        3.00                 0.93
# 14.0          0.410            0.63        3.80                 0.81
# 14.2          0.270            0.49        1.10                 0.54
# 14.3          0.310            0.74        1.80                 0.79
# 15.0          0.210            0.44        2.20                 0.84
# 15.5          0.645            0.49        4.20                 0.74
# 15.6          0.645            0.49        4.20                 0.74
#               0.685            0.76        3.70                 0.68
# 15.9          0.360            0.65        7.50                 0.84
#
#                                                            total_sulfur-dioxide  \
# fixed_acidity volatile_acidity citric_acid residual_sugar
# 3.8           0.310            0.02        11.10                            NaN
# 3.9           0.225            0.40        4.20                             NaN
# 4.2           0.170            0.36        1.80                             NaN
#               0.215            0.23        5.10                             NaN
# 4.4           0.320            0.39        4.30                             NaN
#               0.460            0.10        2.80                             NaN
#               0.540            0.09        5.10                             NaN
# 4.5           0.190            0.21        0.95                             NaN
# 4.6           0.445            0.00        1.40                             NaN
#               0.520            0.15        2.10                            65.0
# 4.7           0.145            0.29        1.00                             NaN
#               0.335            0.14        1.30                             NaN
#               0.455            0.18        1.90                             NaN
#               0.600            0.17        2.30                           106.0
#               0.670            0.09        1.00                             NaN
#               0.785            0.00        3.40                             NaN
# 4.8           0.130            0.32        1.20                             NaN
#               0.170            0.28        2.90                             NaN
#               0.210            0.21        10.20                            NaN
#               0.225            0.38        1.20                             NaN
#               0.260            0.23        10.60                            NaN
#               0.290            0.23        1.10                             NaN
#               0.330            0.00        6.50                             NaN
#               0.340            0.00        6.50                             NaN
#               0.650            0.12        1.10                             NaN
# 4.9           0.235            0.27        11.75                            NaN
#               0.330            0.31        1.20                             NaN
#               0.335            0.14        1.30                             NaN
#               0.345            0.34        1.00                             NaN
#               0.420            0.00        2.10                            42.0
# ...                                                                         ...
# 12.6          0.380            0.66        2.60                            41.0
#               0.390            0.49        2.50                            20.0
#               0.410            0.54        2.80                            41.0
# 12.7          0.590            0.45        2.30                            22.0
#               0.600            0.49        2.80                            19.0
#                                0.65        2.30                            25.0
# 12.8          0.300            0.74        2.60                            28.0
#               0.615            0.66        5.80                            42.0
#               0.840            0.63        2.40                            35.0
# 12.9          0.350            0.49        5.80                            35.0
#               0.500            0.55        2.80                            24.0
# 13.0          0.320            0.65        2.60                            47.0
#               0.470            0.49        4.30                            47.0
# 13.2          0.380            0.55        2.70                            16.0
#               0.460            0.52        2.20                            35.0
# 13.3          0.290            0.75        2.80                            43.0
#               0.340            0.52        3.20                            53.0
#               0.430            0.58        1.90                            40.0
# 13.4          0.270            0.62        2.60                            21.0
# 13.5          0.530            0.79        4.80                            77.0
# 13.7          0.415            0.68        2.90                            43.0
# 13.8          0.490            0.67        3.00                            15.0
# 14.0          0.410            0.63        3.80                            47.0
# 14.2          0.270            0.49        1.10                             NaN
# 14.3          0.310            0.74        1.80                            15.0
# 15.0          0.210            0.44        2.20                            24.0
# 15.5          0.645            0.49        4.20                            23.0
# 15.6          0.645            0.49        4.20                            23.0
#               0.685            0.76        3.70                            43.0
# 15.9          0.360            0.65        7.50                            71.0
#
#                                                            total_sulfur_dioxide
# fixed_acidity volatile_acidity citric_acid residual_sugar
# 3.8           0.310            0.02        11.10                          114.0
# 3.9           0.225            0.40        4.20                           118.0
# 4.2           0.170            0.36        1.80                           161.0
#               0.215            0.23        5.10                           157.0
# 4.4           0.320            0.39        4.30                           127.0
#               0.460            0.10        2.80                           111.0
#               0.540            0.09        5.10                            97.0
# 4.5           0.190            0.21        0.95                           159.0
# 4.6           0.445            0.00        1.40                           178.0
#               0.520            0.15        2.10                             NaN
# 4.7           0.145            0.29        1.00                            90.0
#               0.335            0.14        1.30                           168.0
#               0.455            0.18        1.90                           106.0
#               0.600            0.17        2.30                             NaN
#               0.670            0.09        1.00                             9.0
#               0.785            0.00        3.40                           134.0
# 4.8           0.130            0.32        1.20                            98.0
#               0.170            0.28        2.90                           111.0
#               0.210            0.21        10.20                          112.0
#               0.225            0.38        1.20                           130.0
#               0.260            0.23        10.60                          111.0
#               0.290            0.23        1.10                           180.0
#               0.330            0.00        6.50                           163.0
#               0.340            0.00        6.50                           163.0
#               0.650            0.12        1.10                            10.0
# 4.9           0.235            0.27        11.75                          118.0
#               0.330            0.31        1.20                           150.0
#               0.335            0.14        1.30                           168.0
#               0.345            0.34        1.00                           143.0
#               0.420            0.00        2.10                             NaN
# ...                                                                         ...
# 12.6          0.380            0.66        2.60                             NaN
#               0.390            0.49        2.50                             NaN
#               0.410            0.54        2.80                             NaN
# 12.7          0.590            0.45        2.30                             NaN
#               0.600            0.49        2.80                             NaN
#                                0.65        2.30                             NaN
# 12.8          0.300            0.74        2.60                             NaN
#               0.615            0.66        5.80                             NaN
#               0.840            0.63        2.40                             NaN
# 12.9          0.350            0.49        5.80                             NaN
#               0.500            0.55        2.80                             NaN
# 13.0          0.320            0.65        2.60                             NaN
#               0.470            0.49        4.30                             NaN
# 13.2          0.380            0.55        2.70                             NaN
#               0.460            0.52        2.20                             NaN
# 13.3          0.290            0.75        2.80                             NaN
#               0.340            0.52        3.20                             NaN
#               0.430            0.58        1.90                             NaN
# 13.4          0.270            0.62        2.60                             NaN
# 13.5          0.530            0.79        4.80                             NaN
# 13.7          0.415            0.68        2.90                             NaN
# 13.8          0.490            0.67        3.00                             NaN
# 14.0          0.410            0.63        3.80                             NaN
# 14.2          0.270            0.49        1.10                           156.0
# 14.3          0.310            0.74        1.80                             NaN
# 15.0          0.210            0.44        2.20                             NaN
# 15.5          0.645            0.49        4.20                             NaN
# 15.6          0.645            0.49        4.20                             NaN
#               0.685            0.76        3.70                             NaN
# 15.9          0.360            0.65        7.50                             NaN
#
# [5288 rows x 9 columns]

# %%
#save changes to the next section
df.to_csv('winequality-edited.csv',index=False)

# %%
df.shape[0]
# Out:
# 6497

# %% [markdown]
# # conclusions using query method of pandas
# example of query --> df_m = df.query('diagnosis == "M"')
#
#                      df_a = df.query('income == " >50K"')

# %% [markdown]
# ## do wines with higher alcoholic content receive better ratings?

# %%
# getting the median amount of alcohol content
alcohol_median = df['alcohol'].median()
alcohol_median
# Out:
# 10.3

# %%
# select samples with alcohol content less than the median 

low_alcohol = df.query('alcohol < 10.3')
low_alcohol['quality'].count()
# Out:
# 3177

# %%
high_alcohol = df.query('alcohol >= 10.3')
high_alcohol['quality'].count()
# Out:
# 3320

# %%
low_alcohol = df.query('alcohol < 10.3')
high_alcohol = df.query('alcohol >= 10.3')
num_samples = df.shape[0]
num_samples == low_alcohol['quality'].count() + high_alcohol['quality'].count()
# Out:
# True

# %%
# get mean quality rating for the low alcohol and high alcohol groups
low_alco_quality = low_alcohol['quality'].mean()
low_alco_quality
# Out:
# 5.475920679886686

# %%
high_alco_quality = high_alcohol['quality'].mean()
high_alco_quality
# Out:
# 6.146084337349397

# %% [markdown]
# ### So we can say that higher alcohol content receive better ratings

# %% [markdown]
# ## Do sweeter wines receive better rating ?

# %%
# get median amount of residual sugar
df['residual_sugar'].median()
# Out:
# 3.0

# %%
# select samples with residual sugar less than the median
low_sugar = df.query('residual_sugar < 3.0')

# select samples with residual sugar greater than or equal to the median
high_sugar = df.query('residual_sugar >= 3.0')

# ensure these queries included each sample exactly once
num_samples == low_sugar['quality'].count() + high_sugar['quality'].count() # should be True
# Out:
# True

# %%
# get mean quality rating for the low sugar and high sugar groups
low_sugar['quality'].mean()
# Out:
# 5.808800743724822

# %%
high_sugar['quality'].mean()
# Out:
# 5.82782874617737

# %% [markdown]
# ### so we can say that sweeter wines receive better ratings

# %% [markdown]
# # Plotting with Matplotlib

# %% [markdown]
# ### #1 Do wines with higher alcohol content receive better ratings ?

# %%
# Use query to select each group and get its mean quality
median = df['alcohol'].median()
low = df.query('alcohol < {}'.format(median))
high = df.query('alcohol >= {}'.format(median))

# %%
mean_quality_low = low['quality'].mean()
mean_quality_high = high['quality'].mean()

# %%
#create a bar chart
location = [1,2]
heights = [mean_quality_low,mean_quality_high]
labels = ['Low','High']
plt.bar(location,heights,tick_label=labels,color='g')
plt.title('Average Quality Ratings by Alcohol Content')
plt.xlabel('Alcohol Content')
plt.ylabel('Average Quality Rating');

# %% [markdown]
# ### #2 Do Sweeter wines receive higher ratings?

# %%
meadian = df['residual_sugar'].median()
low = df.query('residual_sugar < {}'.format(median))
high = df.query('residual_sugar >= {}'.format(median))

# %%
sugar_mean_lowquality = low['quality'].mean()
sugar_mean_highquality = high['quality'].mean()

# %%
#create a bar graph
location = [1,2]
heights =[sugar_mean_lowquality,sugar_mean_highquality]
labels = ['low','high']
plt.bar(location,heights,tick_label=labels,color='orange')
plt.title('Average Quality Ratings by residual Content')
plt.xlabel('residual sugar Content')
plt.ylabel('Average Quality Rating');

# %% [markdown]
# ### #3: What level of acidity receives the highest average rating?

# %%
fa_mean = df.groupby('fixed_acidity')['quality'].mean()
fa = fa_mean.mean()
fa
# Out:
# 5.828059057495961

# %%
va_mean = df.groupby('volatile_acidity')['quality'].mean()
va = va_mean.mean()
va
# Out:
# 5.442571682876287

# %%
rs_mean = df.groupby('residual_sugar')['quality'].mean()
rs = rs_mean.mean()
rs
# Out:
# 5.808154369129453

# %%
ca_mean = df.groupby('citric_acid')['quality'].mean()
ca = ca_mean.mean()
ca
# Out:
# 5.662165056090447

# %%
# Create a bar chart with proper labels
heights = [fa,va,rs,ca]
labels = ['fixed_acidity', 'volatile_acidity', 'residual_sugar','ca_mean']
plt.bar([1,2,3,4],heights,tick_label=labels,color='red')
plt.title('Bar chart for all four acidity level')
plt.xlabel('acidity levels')
plt.ylabel('mean quality')
# Out:
# Text(0,0.5,'mean quality')

# %%
heights = [fa,va,rs,ca]
plt.plot([1,2,3,4],heights,linestyle='solid',color='r')

# %% [markdown]
# # Type and Quality Plot with Matplotlib

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
# get counts for each rating and color
red_color_counts = df.groupby(['color_red','quality']).count()['pH']
red_color_counts
# Out:
# color_red  quality
# red        3           10
#            4           53
#            5          681
#            6          638
#            7          199
#            8           18
# Name: pH, dtype: int64

# %%
white_color_counts = df.groupby(['color_white','quality']).count()['pH']
white_color_counts
# Out:
# color_white  quality
# white        3            20
#              4           163
#              5          1457
#              6          2198
#              7           880
#              8           175
#              9             5
# Name: pH, dtype: int64

# %%
# get total counts for each color
color_total_r =df.groupby('color_red').count()['pH']
color_total_r
# Out:
# color_red
# red    1599
# Name: pH, dtype: int64

# %%
color_total_w =df.groupby('color_white').count()['pH']
color_total_w
# Out:
# color_white
# white    4898
# Name: pH, dtype: int64

# %%
# get proportions by dividing red rating counts by total # of red samples
red_proportion = red_color_counts['red'] / color_total_r['red']
red_proportion
# Out:
# quality
# 3    0.006254
# 4    0.033146
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 8    0.011257
# Name: pH, dtype: float64

# %% [markdown]
# #### since the index is upto 8 we have to create a new row as 9 which value is 0

# %%
red_proportion['9'] = 0
red_proportion
# Out:
# quality
# 3    0.006254
# 4    0.033146
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 8    0.011257
# 9    0.000000
# Name: pH, dtype: float64

# %%
white_proportion = white_color_counts['white'] / color_total_w['white']
white_proportion
# Out:
# quality
# 3    0.004083
# 4    0.033279
# 5    0.297468
# 6    0.448755
# 7    0.179665
# 8    0.035729
# 9    0.001021
# Name: pH, dtype: float64

# %% [markdown]
# ### Plot proportions on a bar chart
# Set the x coordinate location for each rating group and and width of each bar.

# %%
ind = np.arange(len(red_proportion))  # the x locations for the groups
width = 0.35

# %%
# plot bars
red_bars = plt.bar(ind,red_proportion, width, color='r', alpha=.7, label='Red Wine')
white_bars = plt.bar(ind + width, white_proportion, width, color='w', alpha=.7, label='White Wine')

# title and labels
plt.ylabel('Proportion')
plt.xlabel('Quality')
plt.title('Proportion by Wine Color and Quality')
locations = ind + width / 2  # xtick locations
labels = ['3', '4', '5', '6', '7', '8', '9']  # xtick labels
plt.xticks(locations, labels)

# legend
plt.legend()

# %%
nbconvert -f blogger-html Case study 1 - detecting red and white wine quality.ipynb
# Out:
#   File "<ipython-input-1-d8ccd1830a2f>", line 1
#     nbconvert -f blogger-html Case study 1 - detecting red and white wine quality.ipynb
#                        ^
# SyntaxError: invalid syntax
